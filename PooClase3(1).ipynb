# %% [markdown]
# <p><img alt="Colaboratory logo" height="140px" src="https://upload.wikimedia.org/wikipedia/commons/c/ce/Logo-ITM-01.png" align="left" hspace="10px" vspace="0px"></p>
# <h1> Introducción a la programación orientada a objetos con python.</h1>
#
# El presente curso hace parte del programa de ciclos de formación en programación con lenguaje Python para el programa de jovenes investigadores e inovadores del ITM. Por William Giraldo Escobar

# %% [markdown]
# # Objetivo
# Hacer una introducción a la programación orientada a objetos y dar elementos teorico practicos para que el estudiante pueda aplicar POO en el desarrollo de programas.

# %% [markdown]
# ![mapaMental.png](data:image/png;base64,...)

# %% [markdown]
# # Programación orientada a procedimientos

# %% [markdown]
# La programación por procedimientos utiliza una lista de instrucciones para indicarle a la computadora qué hacer paso a paso. La programación por procedimientos se basa en, rutinas o subrutinas. Un procedimiento contiene una serie de pasos computacionales a realizar. La programación procedimental también se conoce como programación estructurada.

# %% [markdown]
# # Programación Orientada a Objetos

# %% [markdown]
# Es un paradigma de programación que permite desarrollar aplicaciones complejas manteniendo un código más claro y manejable. Consiste en transladar la naturaleza de los objetos de la vida real al Código de programación.

# %% [markdown]
# # Programación funcional

# %% [markdown]
# Se basa principalmente en el uso de funciones, siendo las mismas practicamente la única herramienta que el lenguaje nos ofrece. Por ello, en lenguajes puramente funcionales como Haskell no existen bucles for o while.

# %% [markdown]
# #1. ¿Que es la programación orientada a ojetos?
# ### ¿Que es un objeto?

# %% [markdown]
# ![Untitled Diagram.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Clase
# Modelo donde se contienen las caracteristicas comunes de un grupo de objetos, está compuesta por atributos y metodos.
# Para crear una clase se utiliza la palabra reservada class y a continuación el nombre de la clase. La definición de la clase se pone entre las llaves de apertura y cierre. El nombre de la clase empieza por letra mayúscula.

# %%
class Carro:

# %% [markdown]
# # Atributos
# Los atributos son las caracterísiticas individuales que diferencian un objeto de otro y determinan su apariencia, estado u otras cualidades. Los atributos se guardan en variables denominadas de instancia, y cada objeto particular puede tener valores distintos para estas variables.
#
# Las variables de instancia también denominados miembros dato, son declaradas en la clase pero sus valores son fijados y cambiados en el objeto.

# %%
color = "azul"
largo = 3 # [m]
numeroLlantas = 4

# %% [markdown]
# # Los constructores
# Un objeto de una clase se crea llamando a una función especial denominada constructor de la clase. El constructor se llama de forma automática cuando se crea un objeto, para situarlo en memoria e inicializar los miembros dato declarados en la clase. El constructor tiene el mismo nombre que la clase. Lo específico del constructor es que no tiene tipo de retorno.

# %% [markdown]
# # 1. Los objetos

# %%
class Carro:
  def __init__(self,color,largo):
    self.color = color
    self.tanqueCom = 10 
    self.largo = largo
    self.numLlantas = 4
    self.velocidad = 0
    self.encendido = False

  def start(self):
    self.encendido = True
    print("el carro está encendido")
    
  
  def acelerar(self,v):
    if self.encendido:
      self.velocidad += v
      print("El carro va a: ", self.velocidad, "Km/h")
    else:
      print("Prenda el carro")
  
  def frenar(self):
    if self.velocidad > 0:
      self.velocidad = 0
      print("El carro está detenido")

# %%
carro = Carro("azul", 3)

# %%
carro2 = Carro("Blanco",4)

# %%
carro2.acelerar(10)

# %%
carro2.start()

# %%
type(carro.largo)

# %% [markdown]
# # 2. Diseño orientado a objetos
# La programación orientada a objetos (POO), como paradigma de programación, se apoya en el diseño orientado a objetos

# %% [markdown]
# ![ClaseCarro.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.1 Abstracción
# Por definición son las características especificas de un objeto, aquellas que lo distinguen de los demás tipos de objetos y que logran definir límites conceptuales respecto a quien está haciendo dicha abstracción del objeto.
#
#
# *   Aislar los elementos (objetos) de su entorno.
# *   Seleccionar las caracteristicas (atributos) de un elemento (objeto)
# *   Identificar los comportamientos (métodos) de un elemento (objeto)

# %% [markdown]
# ## 2.2 Diagramas de clases
# Sirven para representar y visualizar la estructura de las clases que componen un sistema y las relaciones entre ellas.
# Representan la estructura del programa que vamos a desarrollar.

# %% [markdown]
# # 3. Clase Personaje
# Minecraft es un videojuego de construcción, de tipo «mundo abierto» o sandbox creado originalmente por el sueco Markus Persson
#
# ![personajes.png](data:image/png;base64,...)

# %% [markdown]
# Se construirá la etapa inicial de un personaje que tiene las siguientes acciones:
# acciones:
# 1. Moverse libremente a través del mapa, es decir, que el personaje pueda
# subir, bajar, ir a la derecha, ir a la izquierda, la unidad de medida será en
# pixeles (El personaje no podrá moverse en trayectorias diagonales, solo
# de manera horizontal y vertical).
# 2. Recoger botiquines y usarlos cuando se le esté acabando la vida, ya que
# el juego contempla luchas con poderosos enemigos, y para evitar que el
# personaje muera precipitadamente, podrá hacer uso de botiquines (Las
# luchas no están contempladas en la etapa inicial del juego).
# 3. Calcular la distancia recorrida con respecto al origen de coordenadas: Le
# permitirá dar a conocer al jugador qué tan lejano se encuentra de la casa,
# esto es debido a que, para poder guardar la partida, es necesario entrar
# en ella.

# %% [markdown]
# ![Untitled Diagram.drawio.png](data:image/png;base64,...)

# %%
class Personaje:
  def __init__(self,nombre,estatura):
    self.nombre = nombre
    self.estatura = estatura
    self.posicionX = 0
    self.posicionY = 0
    self.numeroBotiquines = 0
    self.vida = 100
    self.distanciaTotal = 0
    
  def moverDerecha(self,d):
    self.posicionX += d
    self.distanciaTotal += d

  def moverIzquierda(self, d):
    self.posicionX -= d
    self.distanciaTotal += d

  def moverArriba(self,d):
    self.posicionY += d
    self.distanciaTotal +=d
  
  def moverAbajo(self, d):
    self.posicionY -= d
    self.distanciaTotal +=d
  
  def recogerBotiquin(self):
    self.numeroBotiquines += 1
    print("Tiene ", self.numeroBotiquines, "botiquin")
  
  def usarBotiquin(self):
    if self.numeroBotiquines > 0:
      v = 100-self.vida
      if self.vida <= 90:
        self.numeroBotiquines -=1
        self.vida += 10
        print("Tiene ", self.numeroBotiquines, "botiquines", "y", self.vida , "de vida")
      elif self.vida > 90 and self.vida < 100:
        self.vida += v
        self.numeroBotiquines -=1
        print("Tiene ", self.numeroBotiquines, "botiquines", "y", self.vida , "de vida")
      else:
        self.vida = 100
        print("No necesita botiquin ")  
    else:
      print("No tiene botiquines")
      
  def calcularDistancia(self):
    return round((self.posicionX**2 + self.posicionY**2)**0.5,3)

# %%
personaje = Personaje("Jack", 1.80)

# %%
personaje.numeroBotiquines
# Out:
# 0

# %%
personaje.moverAbajo(10)
personaje.moverDerecha(5)
personaje.moverIzquierda(3)

# %%
personaje.calcularDistancia()
# Out:
# 10.198

# %%
personaje.recogerBotiquin()
# Out:
# Tiene  1 botiquin

# %%
personaje.usarBotiquin()
# Out:
# No necesita botiquin

# %% [markdown]
# # 4.  Herencias
#
# Otra poderosa característica de la programación orientada a objetos es la capacidad
# de crear una nueva clase extendiendo una clase ya existente. Al extender una clase,
# llamamos a la clase original la clase padre y a la nueva clase clase hija.

# %% [markdown]
# ![espadas.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.1 Nueva clase padre Personaje

# %% [markdown]
# La empresa desea que un personaje regular (Enemigo o jugador) pueda golpear,
# y calcular su distancia con respecto a otro personaje (Esto permitirá realizar el
# cálculo de la cantidad de daño que le ejerce el personaje a otro).
# Por otro lado, el personaje del jugador tendrá las siguientes acciones (Además
# de las que ya puede hacer un personaje regular):
# 1. Moverse libremente a través del mapa, es decir, que el personaje pueda
# subir, bajar, ir a la derecha, ir a la izquierda, la unidad de medida será en
# metros (El personaje no podrá moverse en trayectorias diagonales, solo
# de manera horizontal y vertical).
# 2. Recoger botiquines y usarlos cuando se le esté acabando la vida.
# En cuanto al enemigo o jefe, debe cumplir con las siguientes observaciones
# (Además de las que ya puede hacer un personaje):
# 1. El enemigo estará en una posición fija (No se moverá de ahí).
# 2. El enemigo evolucionará en dos momentos:
# a. El primer momento, cuando el enemigo cuente con una vida de 30
# puntos, la evolución consiste en aumentar su poder de daño en 20
# puntos.
# b. El segundo momento, cuando el enemigo cuente con una vida de
# 10 puntos, la evolución consiste en que la cantidad de daño recibido causado por los golpes del jugador se reducirán a la mitad
# (El cuerpo del enemigo adquiere mejor capacidad de resistencia).

# %% [markdown]
# ![personajes.drawio.png](data:image/png;base64,...)

# %%
class Personaje:
  def __init__(self,nombre, genero, posicionX, posicionY, damage):
    self.nombre = nombre
    self.sexo = genero
    self.posicionX = posicionX
    self.posicionY = posicionY
    self.damage = damage
    self.vida = 100
    
  def golpear(self, p):
    self.vida -= self.damage
    print("se resta ", self.damage, "a vida" )
    
  def recibirImpacto(self, d):
    self.vida -= d
    print("se resta ", d, "a vida" )
      
  def calcularDistanciaRespectoPersonaje(self, p):
    return ((self.posicionX - p.posicionX)**2 + (self.posicionY - p.posicionY)**2)**0.5

# %%
class Jugador(Personaje):
  numeroBotiquines = 0
  
  def moverDerecha(self,d):
    self.posicionX += d  

  def moverIzquierda(self, d):
    self.posicionX -= d    

  def moverArriba(self,d):
    self.posicionY += d    
  
  def moverAbajo(self, d):
    self.posicionY -= d    
  
  def recogerBotiquin(self):
    self.numeroBotiquines += 1
    print("Tiene ", self.numeroBotiquines, "botiquin")
  
  def usarBotiquin(self):
    if numeroBotiquines > 0:
      v = 100-self.vida
      if self.vida <= 90:
        numeroBotiquines -=1
        self.vida += 10
        print("Tiene ", numeroBotiquines, "botiquines", "y", self.vida , "de vida")
      elif self.vida > 90 and self.vida < 100:
        self.vida += v
        numeroBotiquines -=1
        print("Tiene ", numeroBotiquines, "botiquines", "y", self.vida , "de vida")
      else:
        self.vida = 100
        print("No necesita botiquin ")  
    else:
      print("No tiene botiquines")

# %%
class Enemigo(Personaje):
  evolucionesAplicadas = 0
  resistencia = 1
  
  def evolucionar(self):
    if self.vida <= 30 and evolucionesAplicadas == 0:
      self.damage += 20 
      evolucionesAplicadas += 1
    elif self.vida <= 10 and evolucionesAplicadas == 1:
      resistencia += 1
      evolucionesAplicadas +=1

# %%
jugador = Jugador("Jack","m",5, 6, 10)

# %%
type(jugador)
# Out:
# __main__.Jugador

# %%
jugador.recogerBotiquin()
# Out:
# Tiene  1 botiquin

# %%
jugador.numeroBotiquines
# Out:
# 1

# %%
jugador.moverArriba(5)

# %%
jugador.posicionY
# Out:
# 11

# %%
personaje.usarBotiquin()
# Out:
# No tiene botiquines

# %%
personaje1 = Enemigo("Espectro", "m",0, 0, 10)

# %%
personaje1.recibirImpacto(10)
# Out:
# se resta  10 a vida

# %%
personaje1.vida
# Out:
# 90

# %%
personaje1.recogerBotiquin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 personaje1.recogerBotiquin()
#
# AttributeError: 'Enemigo' object has no attribute 'recogerBotiquin'
